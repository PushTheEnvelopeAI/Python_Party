# %% [markdown]
# # 1. Matplotlib Pyplot

# %% [markdown]
# ### Install matplotlib

# %%
# !pip install matplotlib

# %% [markdown]
# ### Import Pyplot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read File using Pandas

# %%
import pandas as pd

data = pd.read_csv("files/stock_data.txt", delimiter=",")
data['Date'] = pd.to_datetime(data['Date'])
data['Change'] = data['Close'] - data['Open']
data['Bin'] = pd.cut(data['Change'], bins=[-200, -2, 2, 200],  labels=['Negative', 'None', 'Positive'])

display(data)
# Out:
#           Date        Open       Close     Change       Bin
# 0   2019-08-12   46.598000   45.801998  -0.796001      None
# 1   2019-08-13   45.762001   47.000000   1.237999      None
# 2   2019-08-14   46.242001   43.924000  -2.318001  Negative
# 3   2019-08-15   44.172001   43.127998  -1.044003      None
# 4   2019-08-16   43.332001   43.987999   0.655998      None
# ..         ...         ...         ...        ...       ...
# 753 2022-08-08  885.000000  871.270020 -13.729980  Negative
# 754 2022-08-09  870.880005  850.000000 -20.880005  Negative
# 755 2022-08-10  891.200012  883.070007  -8.130005  Negative
# 756 2022-08-11  889.539978  859.890015 -29.649963  Negative
# 757 2022-08-12  868.244995  887.179993  18.934998  Positive
#
# [758 rows x 5 columns]

# %% [markdown]
# ### Line Graphs

# %%
plt.figure(figsize=(15,7))
plt.plot(data['Date'], data['Close'], c="red")
plt.plot(data['Date'], data['Open'], c="blue")
plt.title("TSLA Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
plt.figure(figsize=(15,7))
plt.scatter(data['Date'], data['Close'], c="red", s=5)
plt.scatter(data['Date'], data['Open'], c="blue", s=5)
plt.title("TSLA Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### Histograms

# %%
plt.figure(figsize=(15,7))
plt.hist(data['Change'], bins=40)
plt.title("Price Changes")
plt.xlabel("Date")
plt.ylabel("Price Changes")
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
plt.figure(figsize=(12,12))
plt.pie(data['Bin'].value_counts().values, labels = data['Bin'].value_counts().index.values)
plt.title("Ratio of Percent Changes")
plt.show()
